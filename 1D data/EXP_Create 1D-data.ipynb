# %%
# make dataset
import scipy.io
import os
import pandas as pd


directory_path = r'experData.mat'
data = scipy.io.loadmat(directory_path)
ce = data['experData'][0][0]
test_out = ce["y"]
#need test_in
test_out
# Out:
# array([[array([[0.00321558, 0.00393709, 0.00521336, 0.00719677, 0.00993714,
#                 0.01286988, 0.01657986, 0.02224924, 0.03052019, 0.04203847,
#                 0.05797184, 0.07729755, 0.10162868, 0.13177354, 0.16967272,
#                 0.21536104, 0.27092111, 0.33085232, 0.39618013, 0.46877686,
#                 0.55037051, 0.6212646 , 0.68087598, 0.74095739, 0.80405313,
#                 0.85995345, 0.90929005, 0.94736356, 0.97668851, 0.99603815,
#                 1.00825841, 1.01546667, 1.0188216 , 1.02182778, 1.02585788,
#                 1.03041548]])                                              ]],
#       dtype=object)

# %%
ce
# Out:
# array([[(array([[0.00756449, 0.00644647, 0.00621044, 0.00737665, 0.00931856,
#                 0.01016069, 0.01093109, 0.01272643, 0.01574216, 0.01975783,
#                 0.02511374, 0.0310033 , 0.0377559 , 0.04538431, 0.05427641,
#                 0.06672471, 0.0832499 , 0.09631023, 0.10697123, 0.11269577,
#                 0.11564119, 0.12008563, 0.12735708, 0.13791172, 0.155968  ,
#                 0.16203005, 0.15771368, 0.14976415, 0.12907353, 0.1190245 ,
#                 0.1292498 , 0.14170137, 0.15251874, 0.15787511, 0.15778301,
#                 0.15719789]]), array([[0.00321558, 0.00393709, 0.00521336, 0.00719677, 0.00993714,
#                 0.01286988, 0.01657986, 0.02224924, 0.03052019, 0.04203847,
#                 0.05797184, 0.07729755, 0.10162868, 0.13177354, 0.16967272,
#                 0.21536104, 0.27092111, 0.33085232, 0.39618013, 0.46877686,
#                 0.55037051, 0.6212646 , 0.68087598, 0.74095739, 0.80405313,
# ...

# %%
import matplotlib.pyplot as plt
g = ce['v'][0][0]
g[0]
plt.plot(g[0])
